# %%
import torch
from torch_find_peaks import find_peaks_3d

x = torch.randn(32, 32, 32)
find_peaks_3d(x)
# Out:
# (tensor([[ 0,  0,  2],
#          [ 0,  0, 19],
#          [ 0,  0, 24],
#          ...,
#          [31, 29, 22],
#          [31, 29, 24],
#          [31, 30,  7]]),
#  tensor([0.4596, 1.6475, 2.4137,  ..., 1.3951, 2.3854, 1.8612]))
